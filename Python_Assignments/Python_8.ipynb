# %%
import requests
import json
from bs4 import BeautifulSoup
import pandas as pd

def download_and_extract_data(url):
    # Download the data from the API link
    response = requests.get(url)
    data = response.json()

 
    show_id = data['id']
    show_url = data['url']
    show_name = data['name']
    episodes = data['_embedded']['episodes']

    episode_list = []
    for episode in episodes:
        episode_name = episode['name']
        episode_season = episode['season']
        episode_number = episode['number']
        episode_type = episode['type']
        episode_airdate = episode['airdate']
        episode_airtime = episode['airtime']
        episode_runtime = episode['runtime']
        episode_rating = episode['rating']['average']
        episode_summary = BeautifulSoup(episode['summary'], 'html.parser').get_text()
        episode_image_medium = episode['image']['medium']
        episode_image_original = episode['image']['original']

        episode_info = {
            'ID': show_id,
            'URL': show_url,
            'Name': show_name,
            'Episode Name': episode_name,
            'Season': episode_season,
            'Number': episode_number,
            'Type': episode_type,
            'Airdate': episode_airdate,
            'Airtime': episode_airtime,
            'Runtime': episode_runtime,
            'Rating': episode_rating,
            'Summary': episode_summary,
            'Medium Image': episode_image_medium,
            'Original Image': episode_image_original
        }
        episode_list.append(episode_info)


    df = pd.DataFrame(episode_list)
    return df

# %%
url = 'http://api.tvmaze.com/singlesearch/shows?q=westworld&embed=episodes'

df = download_and_extract_data(url)

df
# Out:
#       ID                                          URL       Name  \
# 0   1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 1   1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 2   1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 3   1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 4   1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 5   1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 6   1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 7   1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 8   1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 9   1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 10  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 11  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 12  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 13  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 14  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 15  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 16  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 17  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 18  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 19  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 20  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 21  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 22  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 23  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 24  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 25  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 26  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 27  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 28  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 29  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 30  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 31  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 32  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 33  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 34  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 35  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
#
#                  Episode Name  Season  Number     Type     Airdate Airtime  \
# 0                The Original       1       1  regular  2016-10-02   21:00
# 1                    Chestnut       1       2  regular  2016-10-09   21:00
# 2                   The Stray       1       3  regular  2016-10-16   21:00
# 3           Dissonance Theory       1       4  regular  2016-10-23   21:00
# 4                 Contrapasso       1       5  regular  2016-10-30   21:00
# 5               The Adversary       1       6  regular  2016-11-06   21:00
# 6               Trompe L'Oeil       1       7  regular  2016-11-13   21:00
# 7                 Trace Decay       1       8  regular  2016-11-20   21:00
# 8   The Well-Tempered Clavier       1       9  regular  2016-11-27   21:00
# 9          The Bicameral Mind       1      10  regular  2016-12-04   21:00
# 10         Journey Into Night       2       1  regular  2018-04-22   21:00
# 11                    Reunion       2       2  regular  2018-04-29   21:00
# 12            Virtù e Fortuna       2       3  regular  2018-05-06   21:00
# 13   The Riddle of the Sphinx       2       4  regular  2018-05-13   21:00
# 14               Akane No Mai       2       5  regular  2018-05-20   21:00
# 15                Phase Space       2       6  regular  2018-05-27   21:00
# 16               Les Écorchés       2       7  regular  2018-06-03   21:00
# 17                    Kiksuya       2       8  regular  2018-06-10   21:00
# 18            Vanishing Point       2       9  regular  2018-06-17   21:00
# 19              The Passenger       2      10  regular  2018-06-24   21:00
# 20               Parce Domine       3       1  regular  2020-03-15   21:00
# 21            The Winter Line       3       2  regular  2020-03-22   21:00
# 22       The Absence of Field       3       3  regular  2020-03-29   21:00
# 23       The Mother of Exiles       3       4  regular  2020-04-05   21:00
# 24                      Genre       3       5  regular  2020-04-12   21:00
# 25                Decoherence       3       6  regular  2020-04-19   21:00
# 26                Passed Pawn       3       7  regular  2020-04-26   21:00
# 27              Crisis Theory       3       8  regular  2020-05-03   21:00
# 28               The Auguries       4       1  regular  2022-06-26   21:00
# 29          Well Enough Alone       4       2  regular  2022-07-03   21:00
# 30              Années Folles       4       3  regular  2022-07-10   21:00
# 31            Generation Loss       4       4  regular  2022-07-17   21:00
# 32                   Zhuangzi       4       5  regular  2022-07-24   21:00
# 33                   Fidelity       4       6  regular  2022-07-31   21:00
# 34                   Metanoia       4       7  regular  2022-08-07   21:00
# 35             Que Será, Será       4       8  regular  2022-08-14   21:00
#
#     Runtime  Rating                                            Summary  \
# 0        68     8.0  A woman named Dolores is a free spirit in the ...
# 1        60     7.7  Bernard suspects that someone is sabotaging th...
# 2        60     7.6  Bernard continues to investigate Dolores' supp...
# 3        60     7.9  While Dolores joins William and Logan on their...
# 4        60     8.0  Dolores takes the first step on her path of di...
# 5        60     8.0  While Maeve convinces Felix to show her "upsta...
# 6        60     8.6  While William and Dolores travel to the unclai...
# 7        60     7.9  Bernard tries to cope with what he did under R...
# 8        60     8.5  Bernard forces Robert to take him back into hi...
# 9        90     8.7  Delores finds out the truth about William's fa...
# 10       74     7.8  In the aftermath of the host rebellion, the re...
# 11       60     7.7  Dolores looks for allies sympathetic to her ca...
# 12       60     7.7  While Delores makes a deal with the Confederad...
# 13       71     8.0  William pays his recuperating father-in-law se...
# 14       60     7.6  While Maeve and her people explore Shogun Worl...
# 15       60     7.7  Maeve finds her daughter, Delores finds the "r...
# 16       60     7.9  Charlotte and Bernard review Bernard's memorie...
# 17       60     8.7  Another of Westworld's Host revolutionaries is...
# 18       60     8.4  The Man learns that his grip on reality isn't ...
# 19       90     8.5  The Man faces a personal reckoning, while Akec...
# 20       70     8.0  If you're stuck in a loop, try walking in a st...
# 21       60     7.8  People put up a lot of walls. Bring a sledgeha...
# 22       60     7.8  If you don't like what you see in the mirror, ...
# 23       70     8.0             The truth doesn't always set you free.
# 24       60     7.9                                       Just say no.
# 25       60     7.5  Do a lot of people tell you that you need ther...
# 26       60     7.5  A real friend is one who walks in when the res...
# 27       75     7.7  Time to face the music. Dolores' true intentio...
# 28       55     7.1  Hello again. Don't worry about a thing. It's a...
# 29       55     7.4                    I heard a fly buzz when I died.
# 30       55     7.6  You can never go back again. But if you do, br...
# 31       51     7.7  Should auld acquaintance be forgot and days of...
# 32       60     7.8                                      God is bored.
# 33       60     7.5                       To thine own selves be true.
# 34       60     7.7      You want to have a drink at a time like this?
# 35       60     7.5  Like what I've done with the place? (I just cr...
#
#                                          Medium Image  \
# 0   https://static.tvmaze.com/uploads/images/mediu...
# 1   https://static.tvmaze.com/uploads/images/mediu...
# 2   https://static.tvmaze.com/uploads/images/mediu...
# 3   https://static.tvmaze.com/uploads/images/mediu...
# 4   https://static.tvmaze.com/uploads/images/mediu...
# 5   https://static.tvmaze.com/uploads/images/mediu...
# 6   https://static.tvmaze.com/uploads/images/mediu...
# 7   https://static.tvmaze.com/uploads/images/mediu...
# 8   https://static.tvmaze.com/uploads/images/mediu...
# 9   https://static.tvmaze.com/uploads/images/mediu...
# 10  https://static.tvmaze.com/uploads/images/mediu...
# 11  https://static.tvmaze.com/uploads/images/mediu...
# 12  https://static.tvmaze.com/uploads/images/mediu...
# 13  https://static.tvmaze.com/uploads/images/mediu...
# 14  https://static.tvmaze.com/uploads/images/mediu...
# 15  https://static.tvmaze.com/uploads/images/mediu...
# 16  https://static.tvmaze.com/uploads/images/mediu...
# 17  https://static.tvmaze.com/uploads/images/mediu...
# 18  https://static.tvmaze.com/uploads/images/mediu...
# 19  https://static.tvmaze.com/uploads/images/mediu...
# 20  https://static.tvmaze.com/uploads/images/mediu...
# 21  https://static.tvmaze.com/uploads/images/mediu...
# 22  https://static.tvmaze.com/uploads/images/mediu...
# 23  https://static.tvmaze.com/uploads/images/mediu...
# 24  https://static.tvmaze.com/uploads/images/mediu...
# 25  https://static.tvmaze.com/uploads/images/mediu...
# 26  https://static.tvmaze.com/uploads/images/mediu...
# 27  https://static.tvmaze.com/uploads/images/mediu...
# 28  https://static.tvmaze.com/uploads/images/mediu...
# 29  https://static.tvmaze.com/uploads/images/mediu...
# 30  https://static.tvmaze.com/uploads/images/mediu...
# 31  https://static.tvmaze.com/uploads/images/mediu...
# 32  https://static.tvmaze.com/uploads/images/mediu...
# 33  https://static.tvmaze.com/uploads/images/mediu...
# 34  https://static.tvmaze.com/uploads/images/mediu...
# 35  https://static.tvmaze.com/uploads/images/mediu...
#
#                                        Original Image
# 0   https://static.tvmaze.com/uploads/images/origi...
# 1   https://static.tvmaze.com/uploads/images/origi...
# 2   https://static.tvmaze.com/uploads/images/origi...
# 3   https://static.tvmaze.com/uploads/images/origi...
# 4   https://static.tvmaze.com/uploads/images/origi...
# 5   https://static.tvmaze.com/uploads/images/origi...
# 6   https://static.tvmaze.com/uploads/images/origi...
# 7   https://static.tvmaze.com/uploads/images/origi...
# 8   https://static.tvmaze.com/uploads/images/origi...
# 9   https://static.tvmaze.com/uploads/images/origi...
# 10  https://static.tvmaze.com/uploads/images/origi...
# 11  https://static.tvmaze.com/uploads/images/origi...
# 12  https://static.tvmaze.com/uploads/images/origi...
# 13  https://static.tvmaze.com/uploads/images/origi...
# 14  https://static.tvmaze.com/uploads/images/origi...
# 15  https://static.tvmaze.com/uploads/images/origi...
# 16  https://static.tvmaze.com/uploads/images/origi...
# 17  https://static.tvmaze.com/uploads/images/origi...
# 18  https://static.tvmaze.com/uploads/images/origi...
# 19  https://static.tvmaze.com/uploads/images/origi...
# 20  https://static.tvmaze.com/uploads/images/origi...
# 21  https://static.tvmaze.com/uploads/images/origi...
# 22  https://static.tvmaze.com/uploads/images/origi...
# 23  https://static.tvmaze.com/uploads/images/origi...
# 24  https://static.tvmaze.com/uploads/images/origi...
# 25  https://static.tvmaze.com/uploads/images/origi...
# 26  https://static.tvmaze.com/uploads/images/origi...
# 27  https://static.tvmaze.com/uploads/images/origi...
# 28  https://static.tvmaze.com/uploads/images/origi...
# 29  https://static.tvmaze.com/uploads/images/origi...
# 30  https://static.tvmaze.com/uploads/images/origi...
# 31  https://static.tvmaze.com/uploads/images/origi...
# 32  https://static.tvmaze.com/uploads/images/origi...
# 33  https://static.tvmaze.com/uploads/images/origi...
# 34  https://static.tvmaze.com/uploads/images/origi...
# 35  https://static.tvmaze.com/uploads/images/origi...

# %%
# Optional step : 
output_path = 'movie.csv'
df.to_csv(output_path, index=False)

print("Data loaded and saved as CSV successfully.")
# Out:
# Data loaded and saved as CSV successfully.

# %%
df.head(3)
# Out:
#      ID                                          URL       Name  Episode Name  \
# 0  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld  The Original
# 1  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld      Chestnut
# 2  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld     The Stray
#
#    Season  Number     Type     Airdate Airtime  Runtime  Rating  \
# 0       1       1  regular  2016-10-02   21:00       68     8.0
# 1       1       2  regular  2016-10-09   21:00       60     7.7
# 2       1       3  regular  2016-10-16   21:00       60     7.6
#
#                                              Summary  \
# 0  A woman named Dolores is a free spirit in the ...
# 1  Bernard suspects that someone is sabotaging th...
# 2  Bernard continues to investigate Dolores' supp...
#
#                                         Medium Image  \
# 0  https://static.tvmaze.com/uploads/images/mediu...
# 1  https://static.tvmaze.com/uploads/images/mediu...
# 2  https://static.tvmaze.com/uploads/images/mediu...
#
#                                       Original Image
# 0  https://static.tvmaze.com/uploads/images/origi...
# 1  https://static.tvmaze.com/uploads/images/origi...
# 2  https://static.tvmaze.com/uploads/images/origi...

# %%
season_1 = df[df['Season'] == 1]
season_2 = df[df['Season'] == 2]
season_3 = df[df['Season'] == 3]
season_4 = df[df['Season'] == 4]

# %%
season_1_ratings = sum(season_1['Rating'])/len(season_1)
season_2_ratings = sum(season_2['Rating'])/len(season_2)
season_3_ratings = sum(season_3['Rating'])/len(season_3)
season_4_ratings = sum(season_4['Rating'])/len(season_4)
season_rating = [season_1_ratings, season_2_ratings, season_3_ratings, season_4_ratings]
season_name = [ 'season_1', 'season_2', 'season_3', 'season_4']

# %%
import seaborn as sns 

sns.barplot(data = df, x=season_name, y=season_rating, )
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Get all the episode names, whose average rating is more than 8 for every season:

# %%
df[df['Rating'] > 8][['Episode Name', 'Rating']]
# Out:
#                  Episode Name  Rating
# 6               Trompe L'Oeil     8.6
# 8   The Well-Tempered Clavier     8.5
# 9          The Bicameral Mind     8.7
# 17                    Kiksuya     8.7
# 18            Vanishing Point     8.4
# 19              The Passenger     8.5

# %% [markdown]
# ### Get all the episode names that aired before May 2019

# %%
df['Airdate'].isnull().sum()
# Out:
# 0

# %%
import pandas as pd

df['date_column'] = pd.to_datetime(df['Airdate'])

# Filter the DataFrame for data until May 2019
filtered_df = df[df['date_column'] <= '2019-05']
filtered_df[['Episode Name', 'Airdate']]
# Out:
#                  Episode Name     Airdate
# 0                The Original  2016-10-02
# 1                    Chestnut  2016-10-09
# 2                   The Stray  2016-10-16
# 3           Dissonance Theory  2016-10-23
# 4                 Contrapasso  2016-10-30
# 5               The Adversary  2016-11-06
# 6               Trompe L'Oeil  2016-11-13
# 7                 Trace Decay  2016-11-20
# 8   The Well-Tempered Clavier  2016-11-27
# 9          The Bicameral Mind  2016-12-04
# 10         Journey Into Night  2018-04-22
# 11                    Reunion  2018-04-29
# 12            Virtù e Fortuna  2018-05-06
# 13   The Riddle of the Sphinx  2018-05-13
# 14               Akane No Mai  2018-05-20
# 15                Phase Space  2018-05-27
# 16               Les Écorchés  2018-06-03
# 17                    Kiksuya  2018-06-10
# 18            Vanishing Point  2018-06-17
# 19              The Passenger  2018-06-24

# %% [markdown]
# ### Get the episode name from each season with the highest and lowest rating:

# %%
season_1 = df[df['Season'] == 1]
season_2 = df[df['Season'] == 2]
season_3 = df[df['Season'] == 3]
season_4 = df[df['Season'] == 4]
list_of_seasons = [season_1, season_2, season_3, season_4]

# %%
def low_high_ratings(season):
    """returns Low-High ratings per season"""
    ep_with_low_rat = list(season[season['Rating'] == season['Rating'].min()]['Episode Name'])
    ep_with_high_rat = list(season[season['Rating'] == season['Rating'].max()]['Episode Name'])
    return(
        ep_with_low_rat, ep_with_high_rat
    )

# %%
season_no = 1 
for i in list_of_seasons:
    ep_with_low_rat, ep_with_high_rat = low_high_ratings(i)
    print(f"Episodes with Hight ratings for season {season_no}: ", ep_with_high_rat)
    print(f"Episodes with low ratings for season {season_no}: ", ep_with_low_rat)
    season_no +=1 
    print("----------------------------------------")
# Out:
# Episodes with Hight ratings for season 1:  ['The Bicameral Mind']
# Episodes with low ratings for season 1:  ['The Stray']
# ----------------------------------------
# Episodes with Hight ratings for season 2:  ['Kiksuya']
# Episodes with low ratings for season 2:  ['Akane No Mai']
# ----------------------------------------
# Episodes with Hight ratings for season 3:  ['Parce Domine', 'The Mother of Exiles']
# Episodes with low ratings for season 3:  ['Decoherence', 'Passed Pawn']
# ----------------------------------------
# Episodes with Hight ratings for season 4:  ['Zhuangzi']
# Episodes with low ratings for season 4:  ['The Auguries']
# ----------------------------------------

# %% [markdown]
# #### Another approach:

# %%
df.head(5)
# Out:
#      ID                                          URL       Name  \
# 0  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 1  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 2  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 3  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
# 4  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld
#
#         Episode Name  Season  Number     Type     Airdate Airtime  Runtime  \
# 0       The Original       1       1  regular  2016-10-02   21:00       68
# 1           Chestnut       1       2  regular  2016-10-09   21:00       60
# 2          The Stray       1       3  regular  2016-10-16   21:00       60
# 3  Dissonance Theory       1       4  regular  2016-10-23   21:00       60
# 4        Contrapasso       1       5  regular  2016-10-30   21:00       60
#
#    Rating                                            Summary  \
# 0     8.0  A woman named Dolores is a free spirit in the ...
# 1     7.7  Bernard suspects that someone is sabotaging th...
# 2     7.6  Bernard continues to investigate Dolores' supp...
# 3     7.9  While Dolores joins William and Logan on their...
# 4     8.0  Dolores takes the first step on her path of di...
#
#                                         Medium Image  \
# 0  https://static.tvmaze.com/uploads/images/mediu...
# 1  https://static.tvmaze.com/uploads/images/mediu...
# 2  https://static.tvmaze.com/uploads/images/mediu...
# 3  https://static.tvmaze.com/uploads/images/mediu...
# 4  https://static.tvmaze.com/uploads/images/mediu...
#
#                                       Original Image date_column
# 0  https://static.tvmaze.com/uploads/images/origi...  2016-10-02
# 1  https://static.tvmaze.com/uploads/images/origi...  2016-10-09
# 2  https://static.tvmaze.com/uploads/images/origi...  2016-10-16
# 3  https://static.tvmaze.com/uploads/images/origi...  2016-10-23
# 4  https://static.tvmaze.com/uploads/images/origi...  2016-10-30

# %%
low_rat = df.groupby('Season')['Rating'].min()
high_rat = df.groupby('Season')['Rating'].max()
print(high_rat.items())
print(low_rat.items())
# Out:
# <zip object at 0x0000015341042B40>
# <zip object at 0x0000015341042980>

# %%
def high_low_rat(high_or_low):
    for season, rating in high_or_low.items():
        print(season, rating)
        episodes = list(df[(df['Season'] == int(season)) & (df['Rating'] == rating)]['Episode Name'])
        print(f"Episodes for season {season}: ", episodes)

# %%
high_low_rat(low_rat)
# Out:
# 1 7.6
# Episodes for season 1:  ['The Stray']
# 2 7.6
# Episodes for season 2:  ['Akane No Mai']
# 3 7.5
# Episodes for season 3:  ['Decoherence', 'Passed Pawn']
# 4 7.1
# Episodes for season 4:  ['The Auguries']
